# %%
import csv
import os
from collections import defaultdict
import csv
import random
import json

# %%
corpus_dir = './corpus'
os.makedirs(corpus_dir, exist_ok=True)
contexts = defaultdict(set)

with open('./dataset/SQuAD-v1.1.csv', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        title = row['title'].strip()
        context = row['context'].strip()
        contexts[title].add(context)

for title, ctxs in contexts.items():
    safe_title = "".join(
        c if c.isalnum() or c in "._-" else "_" for c in title)
    file_path = os.path.join(corpus_dir, f"{safe_title}.md")
    with open(file_path, 'w', encoding='utf-8') as out:
        out.write(f"# {title}\n\n")
        out.write('\n\n'.join(sorted(ctxs)))

print(f"Created {len(contexts)} markdown files in {corpus_dir}")

# %%
# Read all questions from the CSV (use the full file if possible, or the .head.csv for a sample)
rows = []
with open('dataset/filtered_questions.csv', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        rows.append(row)

# Use all questions (no random sampling)
result = []
for row in rows:
    result.append({
        "user_input": row["question"],
        "reference": row["answer"],
        "response": "",
        "retrieved_contexts": ""
    })

# Save to JSON file
with open('questions.json', 'w', encoding='utf-8') as f:
    json.dump(result, f, indent=2, ensure_ascii=False)

print(f"Saved {len(result)} questions to ./questions.json")
# Out:
# Saved 500 questions to ./questions.json
