# %% [markdown]
# # RAG Answer Generation
#
# Set the dataset folder and filenames below to use with any RAG dataset (single-hop, multi-hop, lang-RAG).

# %%
import os, json, requests, time
from dotenv import load_dotenv
load_dotenv()
# Set your dataset folder here (e.g. 'single-hop-RAG-dataset', 'multi-hop-RAG-dataset', 'lang-RAG-dataset')
dataset_folder = 'single-hop-RAG-dataset'  # Change as needed
input_json = ('questions.json')  # Change as needed
output_json = ('doc-1_300_bge_small_jinja-reranker-tiny_qwen4B-standard.json')  # data_type, generator, embedding, reranker
log_filename = output_json.replace('.json', '_log.csv')
input_json_path = os.path.join(dataset_folder, input_json)
output_json_path = os.path.join(dataset_folder, output_json)
answer_file_path = os.path.abspath('agent_files/answer.json')
answer_archive_path = os.path.join(dataset_folder, 'answer_generated_all.json')
logging_path = os.path.join(dataset_folder, 'logging.json')
NUM_SAMPLES = 500  # Change as needed
RAG_API_URL = os.environ.get('RAG_API_URL', 'http://127.0.0.1:10000/v1/chat/completions')
RAG_API_METHOD = os.environ.get('RAG_API_METHOD', 'GET').upper()

# %%
def call_rest_api(question):

    # Archive and remove any existing local agent answer file
    if os.path.exists(answer_file_path):
        with open(answer_file_path, 'r', encoding='utf-8') as f:
            existing_data = json.load(f)
        with open(answer_archive_path, 'a', encoding='utf-8') as f:
            json.dump(existing_data, f, indent=2, ensure_ascii=False)
            f.write('\n')
        os.remove(answer_file_path)
    headers = {'Content-Type': 'application/json'}
    payload = {'messages': [{'role': 'user', 'content': question}]}
    start_time = time.time()
    try:
        response = requests.request(
            method=RAG_API_METHOD,
            url=RAG_API_URL,
            headers=headers,
            data=json.dumps(payload),
            timeout=60
        )
        response.raise_for_status()
        response_json = response.json()
    except Exception as e:
        print(f'Request failed: {e}')
        return {'response': '', 'retrieved_contexts': [], 'response_time': None}
    end_time = time.time()
    response_time = end_time - start_time
    try:
        with open(logging_path, 'a', encoding='utf-8') as log_file:
            json.dump(response_json, log_file, indent=2, ensure_ascii=False)
            log_file.write('\n')
    except Exception:
        pass
    # Updated parsing for nested 'Result' key
    message = response_json.get('content', {}).get('Result', {})
    answer = message.get('content', '') if isinstance(message, dict) else ''
    rag_entries = message.get('rag_entries', []) if isinstance(message, dict) else []
    retrieved_contexts = [entry.get('text', '') for entry in rag_entries if isinstance(entry, dict)]
    print(f'Retrieved {len(retrieved_contexts)} chunks for question\n')
    return {'response': answer, 'retrieved_contexts': retrieved_contexts, 'response_time': response_time}

# %%
def update_answers_via_rest(input_path, output_path, num_examples=NUM_SAMPLES):
    """Generate answers via REST API and save results locally only."""
    import os, json
    try:
        with open(input_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
        updated_data = []
        for i, entry in enumerate(data[:num_examples]):
            question = entry.get('user_input', '')
            print(f'🔄 Generating answer for entry {i + 1}/{num_examples}')
            generated = call_rest_api(question)
            updated_entry = entry.copy()
            updated_entry['response'] = generated.get('response', '')
            updated_entry['retrieved_contexts'] = generated.get('retrieved_contexts', [])
            updated_entry['response_time'] = generated.get('response_time', None)
            updated_data.append(updated_entry)
        # Save results
        os.makedirs('results', exist_ok=True)
        results_path = os.path.join('results_final', os.path.basename(output_path))
        with open(results_path, 'w', encoding='utf-8') as f:
            json.dump(updated_data, f, indent=2, ensure_ascii=False)
    except Exception as e:
        print(f'Error during answer generation: 100{e}')

# %%
# save logs and generated answers to results_final folder
os.makedirs('results_final', exist_ok=True)
update_answers_via_rest(input_json_path, output_json_path, NUM_SAMPLES)
# Out:
# 🔄 Generating answer for entry 1/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 2/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 3/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 4/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 5/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 6/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 7/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 8/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 9/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 10/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 11/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 12/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 13/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 14/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 15/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 16/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 17/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 18/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 19/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 20/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 21/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 22/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 23/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 24/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 25/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 26/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 27/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 28/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 29/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 30/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 31/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 32/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 33/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 34/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 35/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 36/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 37/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 38/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 39/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 40/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 41/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 42/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 43/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 44/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 45/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 46/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 47/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 48/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 49/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 50/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 51/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 52/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 53/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 54/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 55/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 56/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 57/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 58/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 59/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 60/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 61/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 62/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 63/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 64/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 65/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 66/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 67/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 68/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 69/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 70/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 71/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 72/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 73/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 74/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 75/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 76/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 77/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 78/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 79/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 80/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 81/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 82/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 83/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 84/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 85/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 86/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 87/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 88/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 89/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 90/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 91/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 92/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 93/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 94/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 95/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 96/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 97/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 98/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 99/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 100/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 101/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 102/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 103/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 104/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 105/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 106/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 107/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 108/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 109/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 110/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 111/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 112/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 113/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 114/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 115/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 116/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 117/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 118/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 119/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 120/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 121/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 122/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 123/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 124/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 125/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 126/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 127/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 128/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 129/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 130/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 131/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 132/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 133/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 134/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 135/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 136/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 137/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 138/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 139/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 140/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 141/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 142/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 143/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 144/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 145/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 146/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 147/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 148/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 149/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 150/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 151/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 152/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 153/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 154/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 155/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 156/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 157/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 158/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 159/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 160/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 161/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 162/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 163/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 164/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 165/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 166/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 167/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 168/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 169/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 170/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 171/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 172/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 173/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 174/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 175/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 176/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 177/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 178/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 179/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 180/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 181/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 182/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 183/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 184/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 185/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 186/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 187/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 188/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 189/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 190/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 191/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 192/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 193/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 194/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 195/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 196/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 197/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 198/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 199/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 200/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 201/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 202/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 203/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 204/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 205/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 206/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 207/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 208/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 209/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 210/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 211/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 212/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 213/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 214/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 215/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 216/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 217/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 218/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 219/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 220/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 221/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 222/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 223/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 224/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 225/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 226/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 227/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 228/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 229/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 230/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 231/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 232/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 233/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 234/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 235/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 236/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 237/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 238/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 239/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 240/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 241/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 242/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 243/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 244/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 245/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 246/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 247/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 248/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 249/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 250/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 251/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 252/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 253/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 254/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 255/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 256/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 257/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 258/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 259/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 260/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 261/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 262/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 263/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 264/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 265/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 266/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 267/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 268/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 269/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 270/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 271/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 272/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 273/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 274/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 275/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 276/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 277/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 278/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 279/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 280/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 281/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 282/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 283/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 284/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 285/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 286/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 287/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 288/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 289/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 290/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 291/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 292/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 293/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 294/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 295/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 296/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 297/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 298/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 299/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 300/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 301/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 302/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 303/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 304/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 305/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 306/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 307/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 308/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 309/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 310/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 311/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 312/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 313/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 314/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 315/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 316/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 317/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 318/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 319/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 320/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 321/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 322/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 323/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 324/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 325/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 326/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 327/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 328/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 329/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 330/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 331/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 332/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 333/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 334/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 335/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 336/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 337/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 338/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 339/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 340/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 341/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 342/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 343/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 344/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 345/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 346/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 347/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 348/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 349/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 350/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 351/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 352/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 353/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 354/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 355/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 356/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 357/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 358/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 359/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 360/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 361/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 362/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 363/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 364/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 365/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 366/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 367/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 368/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 369/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 370/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 371/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 372/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 373/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 374/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 375/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 376/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 377/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 378/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 379/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 380/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 381/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 382/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 383/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 384/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 385/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 386/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 387/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 388/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 389/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 390/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 391/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 392/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 393/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 394/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 395/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 396/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 397/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 398/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 399/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 400/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 401/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 402/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 403/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 404/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 405/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 406/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 407/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 408/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 409/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 410/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 411/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 412/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 413/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 414/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 415/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 416/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 417/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 418/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 419/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 420/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 421/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 422/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 423/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 424/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 425/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 426/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 427/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 428/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 429/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 430/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 431/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 432/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 433/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 434/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 435/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 436/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 437/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 438/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 439/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 440/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 441/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 442/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 443/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 444/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 445/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 446/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 447/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 448/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 449/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 450/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 451/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 452/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 453/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 454/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 455/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 456/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 457/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 458/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 459/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 460/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 461/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 462/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 463/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 464/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 465/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 466/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 467/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 468/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 469/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 470/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 471/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 472/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 473/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 474/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 475/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 476/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 477/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 478/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 479/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 480/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 481/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 482/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 483/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 484/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 485/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 486/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 487/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 488/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 489/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 490/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 491/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 492/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 493/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 494/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 495/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 496/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 497/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 498/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 499/500
# Retrieved 5 chunks for question
#
# 🔄 Generating answer for entry 500/500
# Retrieved 5 chunks for question
